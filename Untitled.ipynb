# %%
import duckdb as ddb

c = ddb.connect("nyc-taxi.duckdb")
c

# %%
yellow_parquets = "data/yellow/data.parquet/*/*.parquet"
green_parquets = "data/green/data.parquet/*/*.parquet"

# %%
import numpy as np
import dask.dataframe as dd

from distributed import Client

# %%
dc = Client()
dc
# Out:
# <Client: 'tcp://127.0.0.1:62962' processes=4 threads=8, memory=16.00 GiB>

# %%
# %%time
engine = "pyarrow"
#engine = "fastparquet"

columns = {
    "VendorID": np.int64,
    "lpep_pickup_datetime": np.datetime64,
    "lpep_dropoff_datetime": np.datetime64,
    "store_and_fwd_flag": str,
    "RatecodeID": np.float64,
    "PULocationID": np.int64,
    "DOLocationID": np.int64,
    "passenger_count": np.float64,
    "trip_distance": np.float64,
    "fare_amount": np.float64,
    "extra": np.float64,
    "mta_tax": np.float64,
    "tip_amount": np.float64,
    "tolls_amount": np.float64,
    # "ehail_fee": np.float64,
    "improvement_surcharge": np.float64,
    "total_amount": np.float64,
    "payment_type": np.float64,
    "trip_type": np.float64,
    # "congestion_surcharge": np.float64,
}
ddf = dd.read_parquet(yellow_parquets, engine=engine)
# Out:
# CPU times: user 15.5 ms, sys: 8.72 ms, total: 24.3 ms
# Wall time: 37.3 ms

# %%
ddf.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
# %%time
ddf.fillna(0).describe().compute()
# Out:
# 2022-07-17 13:43:03,766 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:09,282 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:10,022 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:11,249 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:13,752 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:14,000 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:14,311 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:14,709 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:15,254 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:16,186 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:16,882 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:17,634 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:18,974 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:21,205 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:22,123 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:29,260 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:32,074 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:32,507 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:34,216 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:34,835 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:36,377 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:37,629 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:40,115 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:40,931 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:41,503 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:43,043 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:44,194 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:47,290 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:50,211 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:50,319 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:50,454 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:50,672 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:50,896 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:51,094 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:51,299 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:51,572 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:51,875 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:52,204 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:52,638 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:53,190 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:53,960 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:55,031 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:56,141 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-07-17 13:43:58,774 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-07-17 13:44:10,843 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:44:17,796 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2022-07-17 13:44:37,020 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-07-17 13:44:40,315 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-07-17 13:44:44,308 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~/venvs/ddb/lib/python3.9/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/venvs/ddb/lib/python3.9/site-packages/dask/base.py:603, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     600     keys.append(x.__dask_keys__())
#     601     postcomputes.append(x.__dask_postcompute__())
# --> 603 results = schedule(dsk, keys, **kwargs)
#     604 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:3000, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2998         should_rejoin = False
#    2999 try:
# -> 3000     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3001 finally:
#    3002     for f in futures.values():
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:2174, in Client.gather(self, futures, errors, direct, asynchronous)
#    2172 else:
#    2173     local_worker = None
# -> 2174 return self.sync(
#    2175     self._gather,
#    2176     futures,
#    2177     errors=errors,
#    2178     direct=direct,
#    2179     local_worker=local_worker,
#    2180     asynchronous=asynchronous,
#    2181 )
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
df = ddf.partitions[0].compute()
df.columns
# Out:
# 2022-07-17 13:46:05,062 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.85 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:05,272 - distributed.worker_memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 3.52 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:05,272 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.52 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:05,299 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:54622 (pid=24085) exceeded 95% memory budget. Restarting...
# 2022-07-17 13:46:05,365 - distributed.nanny - WARNING - Restarting worker
# 2022-07-17 13:46:07,000 - distributed.worker_memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:07,000 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:07,102 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:54228 (pid=24083) exceeded 95% memory budget. Restarting...
# 2022-07-17 13:46:07,168 - distributed.nanny - WARNING - Restarting worker
# 2022-07-17 13:46:08,797 - distributed.worker_memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:08,797 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:08,900 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:53827 (pid=24081) exceeded 95% memory budget. Restarting...
# 2022-07-17 13:46:08,965 - distributed.nanny - WARNING - Restarting worker
# 2022-07-17 13:46:10,601 - distributed.worker_memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:10,601 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.48 GiB -- Worker memory limit: 4.00 GiB
# 2022-07-17 13:46:10,700 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:57000 (pid=24087) exceeded 95% memory budget. Restarting...
# 2022-07-17 13:46:10,761 - distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# /Users/cody/files/nyc-taxi-learn/Untitled.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/cody/files/nyc-taxi-learn/Untitled.ipynb#ch0000038?line=0'>1</a> df = ddf.partitions[0].compute()
#       <a href='vscode-notebook-cell:/Users/cody/files/nyc-taxi-learn/Untitled.ipynb#ch0000038?line=1'>2</a> df.columns
#
# File ~/venvs/ddb/lib/python3.9/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/venvs/ddb/lib/python3.9/site-packages/dask/base.py:603, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     600     keys.append(x.__dask_keys__())
#     601     postcomputes.append(x.__dask_postcompute__())
# --> 603 results = schedule(dsk, keys, **kwargs)
#     604 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:3000, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2998         should_rejoin = False
#    2999 try:
# -> 3000     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3001 finally:
#    3002     for f in futures.values():
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:2174, in Client.gather(self, futures, errors, direct, asynchronous)
#    2172 else:
#    2173     local_worker = None
# -> 2174 return self.sync(
#    2175     self._gather,
#    2176     futures,
#    2177     errors=errors,
#    2178     direct=direct,
#    2179     local_worker=local_worker,
#    2180     asynchronous=asynchronous,
#    2181 )
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:405, in sync(loop, func, callback_timeout, *args, **kwargs)
#     403 if error:
#     404     typ, exc, tb = error
# --> 405     raise exc.with_traceback(tb)
#     406 else:
#     407     return result
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/utils.py:378, in sync.<locals>.f()
#     376         future = asyncio.wait_for(future, callback_timeout)
#     377     future = asyncio.ensure_future(future)
# --> 378     result = yield future
#     379 except Exception:
#     380     error = sys.exc_info()
#
# File ~/venvs/ddb/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File ~/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:2037, in Client._gather(self, futures, errors, direct, local_worker)
#    2035         exc = CancelledError(key)
#    2036     else:
# -> 2037         raise exception.with_traceback(traceback)
#    2038     raise exc
#    2039 if errors == "skip":
#
# KilledWorker: ("('read-parquet-f3e0dd1b8d6f01c6d8ee1c7cc5ab8c3a', 0)", <WorkerState 'tcp://127.0.0.1:57000', name: 0, status: closed, memory: 0, processing: 1>)

# %%
# %%time

operators = ["count", "favg", "stddev_pop", "min", "max"]

in_select = ""
for column in columns:
    if columns[column] in (np.int64, np.float64):
        for operator in operators:
            in_select += f"\n{operator}({column}),"
            if columns[column] is np.float64:
                for quantile in range(25, 100, 25):
                    in_select += f"\nquantile_disc({column}, {quantile/100}),"

query = f"""
select 
    {in_select.lstrip().rstrip(",")}
from yellow 
--from read_parquet('{green_parquets}')
""".lstrip().rstrip()

# query += "\ngroup by"
# for column in columns:
#    query += f" {column},"
# query = query.rstrip(",")

print(query)

out = c.execute(query).fetchall()
out
# Out:
# select
#     count(VendorID),
# favg(VendorID),
# stddev_pop(VendorID),
# min(VendorID),
# max(VendorID),
# count(RatecodeID),
# quantile_disc(RatecodeID, 0.25),
# quantile_disc(RatecodeID, 0.5),
# quantile_disc(RatecodeID, 0.75),
# favg(RatecodeID),
# quantile_disc(RatecodeID, 0.25),
# quantile_disc(RatecodeID, 0.5),
# quantile_disc(RatecodeID, 0.75),
# stddev_pop(RatecodeID),
# quantile_disc(RatecodeID, 0.25),
# quantile_disc(RatecodeID, 0.5),
# quantile_disc(RatecodeID, 0.75),
# min(RatecodeID),
# quantile_disc(RatecodeID, 0.25),
# quantile_disc(RatecodeID, 0.5),
# quantile_disc(RatecodeID, 0.75),
# max(RatecodeID),
# quantile_disc(RatecodeID, 0.25),
# quantile_disc(RatecodeID, 0.5),
# quantile_disc(RatecodeID, 0.75),
# count(PULocationID),
# favg(PULocationID),
# stddev_pop(PULocationID),
# min(PULocationID),
# max(PULocationID),
# count(DOLocationID),
# favg(DOLocationID),
# stddev_pop(DOLocationID),
# min(DOLocationID),
# max(DOLocationID),
# count(passenger_count),
# quantile_disc(passenger_count, 0.25),
# quantile_disc(passenger_count, 0.5),
# quantile_disc(passenger_count, 0.75),
# favg(passenger_count),
# quantile_disc(passenger_count, 0.25),
# quantile_disc(passenger_count, 0.5),
# quantile_disc(passenger_count, 0.75),
# stddev_pop(passenger_count),
# quantile_disc(passenger_count, 0.25),
# quantile_disc(passenger_count, 0.5),
# quantile_disc(passenger_count, 0.75),
# min(passenger_count),
# quantile_disc(passenger_count, 0.25),
# quantile_disc(passenger_count, 0.5),
# quantile_disc(passenger_count, 0.75),
# max(passenger_count),
# quantile_disc(passenger_count, 0.25),
# quantile_disc(passenger_count, 0.5),
# quantile_disc(passenger_count, 0.75),
# count(trip_distance),
# quantile_disc(trip_distance, 0.25),
# quantile_disc(trip_distance, 0.5),
# quantile_disc(trip_distance, 0.75),
# favg(trip_distance),
# quantile_disc(trip_distance, 0.25),
# quantile_disc(trip_distance, 0.5),
# quantile_disc(trip_distance, 0.75),
# stddev_pop(trip_distance),
# quantile_disc(trip_distance, 0.25),
# quantile_disc(trip_distance, 0.5),
# quantile_disc(trip_distance, 0.75),
# min(trip_distance),
# quantile_disc(trip_distance, 0.25),
# quantile_disc(trip_distance, 0.5),
# quantile_disc(trip_distance, 0.75),
# max(trip_distance),
# quantile_disc(trip_distance, 0.25),
# quantile_disc(trip_distance, 0.5),
# quantile_disc(trip_distance, 0.75),
# count(fare_amount),
# quantile_disc(fare_amount, 0.25),
# quantile_disc(fare_amount, 0.5),
# quantile_disc(fare_amount, 0.75),
# favg(fare_amount),
# quantile_disc(fare_amount, 0.25),
# quantile_disc(fare_amount, 0.5),
# quantile_disc(fare_amount, 0.75),
# stddev_pop(fare_amount),
# quantile_disc(fare_amount, 0.25),
# quantile_disc(fare_amount, 0.5),
# quantile_disc(fare_amount, 0.75),
# min(fare_amount),
# quantile_disc(fare_amount, 0.25),
# quantile_disc(fare_amount, 0.5),
# quantile_disc(fare_amount, 0.75),
# max(fare_amount),
# quantile_disc(fare_amount, 0.25),
# quantile_disc(fare_amount, 0.5),
# quantile_disc(fare_amount, 0.75),
# count(extra),
# quantile_disc(extra, 0.25),
# quantile_disc(extra, 0.5),
# quantile_disc(extra, 0.75),
# favg(extra),
# quantile_disc(extra, 0.25),
# quantile_disc(extra, 0.5),
# quantile_disc(extra, 0.75),
# stddev_pop(extra),
# quantile_disc(extra, 0.25),
# quantile_disc(extra, 0.5),
# quantile_disc(extra, 0.75),
# min(extra),
# quantile_disc(extra, 0.25),
# quantile_disc(extra, 0.5),
# quantile_disc(extra, 0.75),
# max(extra),
# quantile_disc(extra, 0.25),
# quantile_disc(extra, 0.5),
# quantile_disc(extra, 0.75),
# count(mta_tax),
# quantile_disc(mta_tax, 0.25),
# quantile_disc(mta_tax, 0.5),
# quantile_disc(mta_tax, 0.75),
# favg(mta_tax),
# quantile_disc(mta_tax, 0.25),
# quantile_disc(mta_tax, 0.5),
# quantile_disc(mta_tax, 0.75),
# stddev_pop(mta_tax),
# quantile_disc(mta_tax, 0.25),
# quantile_disc(mta_tax, 0.5),
# quantile_disc(mta_tax, 0.75),
# min(mta_tax),
# quantile_disc(mta_tax, 0.25),
# quantile_disc(mta_tax, 0.5),
# quantile_disc(mta_tax, 0.75),
# max(mta_tax),
# quantile_disc(mta_tax, 0.25),
# quantile_disc(mta_tax, 0.5),
# quantile_disc(mta_tax, 0.75),
# count(tip_amount),
# quantile_disc(tip_amount, 0.25),
# quantile_disc(tip_amount, 0.5),
# quantile_disc(tip_amount, 0.75),
# favg(tip_amount),
# quantile_disc(tip_amount, 0.25),
# quantile_disc(tip_amount, 0.5),
# quantile_disc(tip_amount, 0.75),
# stddev_pop(tip_amount),
# quantile_disc(tip_amount, 0.25),
# quantile_disc(tip_amount, 0.5),
# quantile_disc(tip_amount, 0.75),
# min(tip_amount),
# quantile_disc(tip_amount, 0.25),
# quantile_disc(tip_amount, 0.5),
# quantile_disc(tip_amount, 0.75),
# max(tip_amount),
# quantile_disc(tip_amount, 0.25),
# quantile_disc(tip_amount, 0.5),
# quantile_disc(tip_amount, 0.75),
# count(tolls_amount),
# quantile_disc(tolls_amount, 0.25),
# quantile_disc(tolls_amount, 0.5),
# quantile_disc(tolls_amount, 0.75),
# favg(tolls_amount),
# quantile_disc(tolls_amount, 0.25),
# quantile_disc(tolls_amount, 0.5),
# quantile_disc(tolls_amount, 0.75),
# stddev_pop(tolls_amount),
# quantile_disc(tolls_amount, 0.25),
# quantile_disc(tolls_amount, 0.5),
# quantile_disc(tolls_amount, 0.75),
# min(tolls_amount),
# quantile_disc(tolls_amount, 0.25),
# quantile_disc(tolls_amount, 0.5),
# quantile_disc(tolls_amount, 0.75),
# max(tolls_amount),
# quantile_disc(tolls_amount, 0.25),
# quantile_disc(tolls_amount, 0.5),
# quantile_disc(tolls_amount, 0.75),
# count(improvement_surcharge),
# quantile_disc(improvement_surcharge, 0.25),
# quantile_disc(improvement_surcharge, 0.5),
# quantile_disc(improvement_surcharge, 0.75),
# favg(improvement_surcharge),
# quantile_disc(improvement_surcharge, 0.25),
# quantile_disc(improvement_surcharge, 0.5),
# quantile_disc(improvement_surcharge, 0.75),
# stddev_pop(improvement_surcharge),
# quantile_disc(improvement_surcharge, 0.25),
# quantile_disc(improvement_surcharge, 0.5),
# quantile_disc(improvement_surcharge, 0.75),
# min(improvement_surcharge),
# quantile_disc(improvement_surcharge, 0.25),
# quantile_disc(improvement_surcharge, 0.5),
# quantile_disc(improvement_surcharge, 0.75),
# max(improvement_surcharge),
# quantile_disc(improvement_surcharge, 0.25),
# quantile_disc(improvement_surcharge, 0.5),
# quantile_disc(improvement_surcharge, 0.75),
# count(total_amount),
# quantile_disc(total_amount, 0.25),
# quantile_disc(total_amount, 0.5),
# quantile_disc(total_amount, 0.75),
# favg(total_amount),
# quantile_disc(total_amount, 0.25),
# quantile_disc(total_amount, 0.5),
# quantile_disc(total_amount, 0.75),
# stddev_pop(total_amount),
# quantile_disc(total_amount, 0.25),
# quantile_disc(total_amount, 0.5),
# quantile_disc(total_amount, 0.75),
# min(total_amount),
# quantile_disc(total_amount, 0.25),
# quantile_disc(total_amount, 0.5),
# quantile_disc(total_amount, 0.75),
# max(total_amount),
# quantile_disc(total_amount, 0.25),
# quantile_disc(total_amount, 0.5),
# quantile_disc(total_amount, 0.75),
# count(payment_type),
# quantile_disc(payment_type, 0.25),
# quantile_disc(payment_type, 0.5),
# quantile_disc(payment_type, 0.75),
# favg(payment_type),
# quantile_disc(payment_type, 0.25),
# quantile_disc(payment_type, 0.5),
# quantile_disc(payment_type, 0.75),
# stddev_pop(payment_type),
# quantile_disc(payment_type, 0.25),
# quantile_disc(payment_type, 0.5),
# quantile_disc(payment_type, 0.75),
# min(payment_type),
# quantile_disc(payment_type, 0.25),
# quantile_disc(payment_type, 0.5),
# quantile_disc(payment_type, 0.75),
# max(payment_type),
# quantile_disc(payment_type, 0.25),
# quantile_disc(payment_type, 0.5),
# quantile_disc(payment_type, 0.75),
# count(trip_type),
# quantile_disc(trip_type, 0.25),
# quantile_disc(trip_type, 0.5),
# quantile_disc(trip_type, 0.75),
# favg(trip_type),
# quantile_disc(trip_type, 0.25),
# quantile_disc(trip_type, 0.5),
# quantile_disc(trip_type, 0.75),
# stddev_pop(trip_type),
# quantile_disc(trip_type, 0.25),
# quantile_disc(trip_type, 0.5),
# quantile_disc(trip_type, 0.75),
# min(trip_type),
# quantile_disc(trip_type, 0.25),
# quantile_disc(trip_type, 0.5),
# quantile_disc(trip_type, 0.75),
# max(trip_type),
# quantile_disc(trip_type, 0.25),
# quantile_disc(trip_type, 0.5),
# quantile_disc(trip_type, 0.75)
# from yellow
# --from read_parquet('data/green/data.parquet/*/*.parquet')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File <timed exec>:26, in <module>
#
# RuntimeError: Binder Error: Referenced column "trip_type" not found in FROM clause!
# Candidate bindings: "yellow.trip_distance"
# LINE 237: count(trip_type),
#                 ^

# %%
# %%time
query = f"""
select
    *
from yellow
--limit 10
""".lstrip()

out = c.execute(query).fetchall()
out
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-9485' coro=<Client._gather.<locals>.wait() done, defined at /Users/cody/venvs/ddb/lib/python3.9/site-packages/distributed/client.py:2002> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/cody/venvs/ddb/lib/python3.9/site-packages/distributed/client.py", line 2011, in wait
#     raise AllExit()
# distributed.client.AllExit
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x13f490f70>>
# Traceback (most recent call last):
#   File "/Users/cody/venvs/ddb/lib/python3.9/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# 2022-07-17 13:47:37,784 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2022-07-17 13:47:37,910 - distributed.nanny - WARNING - Restarting worker

# %%
# %%time

query = f"""
select 
    max(fare_amount)
from read_parquet('{green_parquets}')
""".lstrip()

max_fare = c.execute(query).fetchall()[0][0]
max_fare

# %%
# %%time

query = f"""
select 
    trip_distance,
    passenger_count,
    tip_amount,
    tolls_amount,
    ehail_fee,
    mta_tax,
    improvement_surcharge,
    total_amount,
    payment_type,
    congestion_surcharge
from read_parquet('{green_parquets}')
where fare_amount={max_fare}
""".lstrip()

out = c.execute(query).fetchall()
out

# %%
df.columns

# %%
import seaborn as sns

# %%
query = f"""
select 
    tip_amount
from yellow
where tip_amount is not null
order by tip_amount desc
limit 100000
""".lstrip()

out = c.execute(query)
out

# %%
test = out.df()
test.values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
sns.set(rc={"figure.figsize": (16, 18)})
plt.style.use("dark_background")

# %%
sns.displot(data=test, rug=True, height=10, aspect=2.0, kind="hist")
plt.xlim(25, 200)
plt.ylim(0, 12000)

# %%
query = f"""
select 
    total_amount,
    fare_amount,
    tip_amount
from yellow
where tip_amount is not null
and tip_amount < 100000
and total_amount < 2000
order by tip_amount desc
limit 100000
""".lstrip()

out = c.execute(query)
out

# %%
test = out.df()
test.head()

# %%
sns.scatterplot(y=test["tip_amount"].values, x=test["total_amount"].values)

# %%
query = f"""
select 
    count(*)
from yellow
where fare_amount < 0
or total_amount < 0
""".lstrip()

out = c.execute(query)
out.fetchall()

# %%
query = f"""
select 
    count(*)
from yellow
where tip_amount < 0
""".lstrip()

out = c.execute(query)
out.fetchall()
